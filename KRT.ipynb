# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
train_df['source'] = 'train'
test_df['source'] = 'test'
df = pd.concat([train_df,test_df],ignore_index=True)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.apply(lambda x:sum(x.isnull()))
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %%
cat = [x for x in df.dtypes.index if df.dtypes[x] == 'object']
cat
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'source']

# %%
cat_Id = [x for x in cat if x not in ['Item_Identifier','Outlet_Identifier','source']]
cat_Id
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
mean = df['Item_Weight'].mean()

# %%
df['Item_Weight'].fillna(mean, inplace=True)

# %%
df.apply(lambda x:sum(x.isnull()))
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
df.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  14204.000000     14204.000000  14204.000000               14204.000000
# mean      12.792854         0.065953    141.004977                1997.830681
# std        4.234226         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        9.300000         0.027036     94.012000                1987.000000
# 50%       12.792854         0.054021    142.247000                1999.000000
# 75%       16.000000         0.094037    185.855600                2004.000000
# max       21.350000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df['Outlet'] = le.fit_transform(df['Outlet_Identifier'])
df['Outlet']
# Out:
# 0        9
# 1        3
# 2        9
# 3        0
# 4        1
#         ..
# 14199    8
# 14200    3
# 14201    7
# 14202    2
# 14203    7
# Name: Outlet, Length: 14204, dtype: int32

# %%
from sklearn.linear_model import LinearRegression

# %%
df.drop(['Item_Fat_Content','Outlet_Size','Item_Type'],axis=1,inplace=True)

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0               FDA15         9.30         0.016047  249.8092
# 1               DRC01         5.92         0.019278   48.2692
# 2               FDN15        17.50         0.016760  141.6180
# 3               FDX07        19.20         0.000000  182.0950
# 4               NCD19         8.93         0.000000   53.8614
# ...               ...          ...              ...       ...
# 14199           FDB58        10.50         0.013496  141.3154
# 14200           FDD47         7.60         0.142991  169.1448
# 14201           NCO17        10.00         0.073529  118.7440
# 14202           FDJ26        15.30         0.000000  214.6218
# 14203           FDU37         9.50         0.104720   79.7960
#
#       Outlet_Identifier  Outlet_Establishment_Year Outlet_Location_Type  \
# 0                OUT049                       1999               Tier 1
# 1                OUT018                       2009               Tier 3
# ...

# %%
le = LabelEncoder()
df['Outlet_Type'] = le.fit_transform(df['Outlet_Type'])

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0               FDA15         9.30         0.016047  249.8092
# 1               DRC01         5.92         0.019278   48.2692
# 2               FDN15        17.50         0.016760  141.6180
# 3               FDX07        19.20         0.000000  182.0950
# 4               NCD19         8.93         0.000000   53.8614
# ...               ...          ...              ...       ...
# 14199           FDB58        10.50         0.013496  141.3154
# 14200           FDD47         7.60         0.142991  169.1448
# 14201           NCO17        10.00         0.073529  118.7440
# 14202           FDJ26        15.30         0.000000  214.6218
# 14203           FDU37         9.50         0.104720   79.7960
#
#       Outlet_Identifier  Outlet_Establishment_Year Outlet_Location_Type  \
# 0                OUT049                       1999               Tier 1
# 1                OUT018                       2009               Tier 3
# ...

# %%
train = df.loc[df['source'] == 'train']
test = df.loc[df['source'] == 'test']

# %%
train
# Out:
#      Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0              FDA15        9.300         0.016047  249.8092
# 1              DRC01        5.920         0.019278   48.2692
# 2              FDN15       17.500         0.016760  141.6180
# 3              FDX07       19.200         0.000000  182.0950
# 4              NCD19        8.930         0.000000   53.8614
# ...              ...          ...              ...       ...
# 8518           FDF22        6.865         0.056783  214.5218
# 8519           FDS36        8.380         0.046982  108.1570
# 8520           NCJ29       10.600         0.035186   85.1224
# 8521           FDN46        7.210         0.145221  103.1332
# 8522           DRG01       14.800         0.044878   75.4670
#
#      Outlet_Identifier  Outlet_Establishment_Year Outlet_Location_Type  \
# 0               OUT049                       1999               Tier 1
# 1               OUT018                       2009               Tier 3
# ...

# %%
test.drop(['Item_Outlet_Sales','source'],axis=1,inplace=True)
# Out:
# C:\Users\abcd\.anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
test
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 8523            FDW58    20.750000         0.007565  107.8622
# 8524            FDW14     8.300000         0.038428   87.3198
# 8525            NCN55    14.600000         0.099575  241.7538
# 8526            FDQ58     7.315000         0.015388  155.0340
# 8527            FDY38    12.792854         0.118599  234.2300
# ...               ...          ...              ...       ...
# 14199           FDB58    10.500000         0.013496  141.3154
# 14200           FDD47     7.600000         0.142991  169.1448
# 14201           NCO17    10.000000         0.073529  118.7440
# 14202           FDJ26    15.300000         0.000000  214.6218
# 14203           FDU37     9.500000         0.104720   79.7960
#
#       Outlet_Identifier  Outlet_Establishment_Year Outlet_Location_Type  \
# 8523             OUT049                       1999               Tier 1
# 8524             OUT017                       2007               Tier 2
# ...

# %%
lr = LinearRegression(normalize=True)

# %%
X_train = train.drop(['Item_Outlet_Sales','Item_Identifier','Outlet_Identifier'],axis=1)
Y_train = train['Item_Outlet_Sales']
X_test = test.drop(['Item_Identifier','Outlet_Identifier'],axis=1).copy()

# %%
X_train
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#      Outlet_Location_Type  Outlet_Type source  Outlet
# ...

# %%
le = LabelEncoder()
X_train['Outlet_Location_Type'] = le.fit_transform(X_train['Outlet_Location_Type'])

# %%
X_train=X_train.drop(['source'],axis=1)

# %%
le = LabelEncoder()
X_test['Outlet_Location_Type'] = le.fit_transform(X_test['Outlet_Location_Type'])
X_test
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 8523     20.750000         0.007565  107.8622                       1999
# 8524      8.300000         0.038428   87.3198                       2007
# 8525     14.600000         0.099575  241.7538                       1998
# 8526      7.315000         0.015388  155.0340                       2007
# 8527     12.792854         0.118599  234.2300                       1985
# ...            ...              ...       ...                        ...
# 14199    10.500000         0.013496  141.3154                       1997
# 14200     7.600000         0.142991  169.1448                       2009
# 14201    10.000000         0.073529  118.7440                       2002
# 14202    15.300000         0.000000  214.6218                       2007
# 14203     9.500000         0.104720   79.7960                       2002
#
#        Outlet_Location_Type  Outlet_Type  Outlet
# ...

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
lr_pred = lr.predict(X_test)

# %%
lr_accuracy = round(lr.score(X_train,Y_train) * 100,2)
lr_accuracy
# Out:
# 50.18

# %%
linear = pd.DataFrame({
    'Item_Identifier':test_df['Item_Identifier'],
    'Outlet_Identifier':test_df['Outlet_Identifier'],
    'Item_Outlet_Sales': lr_pred
},columns=['Item_Identifier','Outlet_Identifier','Item_Outlet_Sales'])

# %%
linear.to_csv('final.csv',index=False)

# %%
linear
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049        1901.685003
# 1              FDW14            OUT017        1045.497498
# 2              NCN55            OUT010        2342.457536
# 3              FDQ58            OUT017        2139.807350
# 4              FDY38            OUT027        5075.389460
# ...              ...               ...                ...
# 5676           FDB58            OUT046        2369.909647
# 5677           FDD47            OUT018        2974.032505
# 5678           NCO17            OUT045        1774.778192
# 5679           FDJ26            OUT017        3088.289218
# 5680           FDU37            OUT045        1115.361022
#
# [5681 rows x 3 columns]
